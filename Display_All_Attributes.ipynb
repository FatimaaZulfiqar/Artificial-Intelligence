# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaaZulfiqar/Artificial-Intelligence/blob/main/Display_All_Attributes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def __init__(self, student_id, name, student_class):
        self.student_id = student_id
        self.name = name
        self.student_class = student_class

    def display(self):
        for key, value in self.__dict__.items():
            print(key, ":", value)

s = Student(1, "Fatima", "BSE")
s.display()
# Out:
# student_id : 1
# name : Fatima
# student_class : BSE

# %%
class Student:
    def __init__(self, student_id, name):
        self.student_id = student_id
        self.name = name

    def display(self):
        print(f"ID: {self.student_id}, Name: {self.name}")

student1 = Student(1, "Fatima")
student2 = Student(2, "Zara")

student1.display()
student2.display()
# Out:
# ID: 1, Name: Fatima
# ID: 2, Name: Zara

# %%
import sys

class Student:
    def __init__(self, name):
        self.name = name

s = Student("Fatima")

print("Memory size:", sys.getsizeof(s))
# Out:
# Memory size: 48

# %%
class Student:
    __slots__ = ['name']

    def __init__(self, name):
        self.name = name

s = Student("Fatima")

import sys
print("Memory with slots:", sys.getsizeof(s))
# Out:
# Memory with slots: 40
