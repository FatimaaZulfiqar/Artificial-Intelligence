# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaaZulfiqar/Artificial-Intelligence/blob/main/DFS%20on%20Romania%20Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
graph = {
    'Arad': [('Zerind', 75), ('Timisoara', 118), ('Sibiu', 140)],
    'Zerind': [('Arad', 75), ('Oradea', 71)],
    'Oradea': [('Zerind', 71), ('Sibiu', 151)],
    'Timisoara': [('Arad', 118), ('Lugoj', 111)],
    'Lugoj': [('Timisoara', 111), ('Mehadia', 70)],
    'Mehadia': [('Lugoj', 70), ('Drobeta', 75)],
    'Drobeta': [('Mehadia', 75), ('Craiova', 120)],
    'Craiova': [('Drobeta', 120), ('Pitesti', 138), ('Rimnicu Vilcea', 146)],
    'Sibiu': [('Arad', 140), ('Oradea', 151), ('Fagaras', 99), ('Rimnicu Vilcea', 80)],
    'Rimnicu Vilcea': [('Sibiu', 80), ('Craiova', 146), ('Pitesti', 97)],
    'Fagaras': [('Sibiu', 99), ('Bucharest', 211)],
    'Pitesti': [('Rimnicu Vilcea', 97), ('Craiova', 138), ('Bucharest', 101)],
    'Bucharest': []
}

def dfs(graph, current, goal, visited, path, cost):
    visited.add(current)
    path.append(current)

    if current == goal:
        return path, cost

    for neighbor, distance in graph[current]:
        if neighbor not in visited:
            result = dfs(graph, neighbor, goal, visited, path, cost + distance)
            if result:
                return result

    path.pop()
    return None


# Driver Code
start = 'Arad'
goal = 'Bucharest'

visited = set()
result = dfs(graph, start, goal, visited, [], 0)

if result:
    path, total_cost = result
    print("Path:", " -> ".join(path))
    print("Total Distance:", total_cost)
else:
    print("No path found")
# Out:
# Path: Arad -> Zerind -> Oradea -> Sibiu -> Fagaras -> Bucharest
# Total Distance: 607
